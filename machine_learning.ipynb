# %%
import pandas as pd

# %%
stats = pd.read_csv("player_mvp_stats.csv", index_col=0)

# %%
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 15231   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 15232     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 15233  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 15234      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 15235      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# 0          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 1          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 2          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 3          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 4          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# ...        ...    ...                 ...  ..  ..    ...  ...    ...    ...
# 15231      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 15232      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 15233      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 15234      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 15235      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
#
#         SRS
# 0      6.73
# 1      6.73
# 2      6.73
# 3      6.73
# 4      6.73
# ...     ...
# 15231 -0.45
# 15232 -0.45
# 15233 -0.45
# 15234 -0.45
# 15235 -0.45
#
# [15236 rows x 41 columns]

# %%
stats.sort_values("Share", ascending=False).head(20)
# Out:
#                       Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 6096           Stephen Curry  PG   27  GSW  79  79  34.2  10.2  20.2  0.504
# 14048           LeBron James  PF   28  MIA  76  76  37.9  10.1  17.8  0.565
# 143         Shaquille O'Neal   C   27  LAL  79  79  40.0  12.1  21.1  0.574
# 14913          Kevin Garnett  PF   27  MIN  82  82  39.4   9.8  19.6  0.499
# 6884            Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503
# 11346         Michael Jordan  SG   32  CHI  82  82  37.7  11.2  22.6  0.495
# 6076            LeBron James  SF   25  CLE  76  76  39.0  10.1  20.1  0.503
# 13220           Derrick Rose  PG   22  CHI  81  81  37.4   8.8  19.7  0.445
# 6059            LeBron James  SF   24  CLE  81  81  37.7   9.7  19.9  0.489
# 698             Nikola Jokić   C   25  DEN  72  72  34.6  10.2  18.0  0.566
# 1002            James Harden  SG   28  HOU  72  72  35.4   9.0  20.1  0.449
# 13354  Giannis Antetokounmpo  PF   25  MIL  63  63  30.4  10.9  19.7  0.553
# 10738         Michael Jordan  SG   28  CHI  80  80  38.8  11.8  22.7  0.519
# 11374         Michael Jordan  SG   34  CHI  82  82  38.8  10.7  23.1  0.465
# 12379  Giannis Antetokounmpo  PF   24  MIL  72  72  32.8  10.0  17.3  0.578
# 10725         Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539
# 6601           Stephen Curry  PG   26  GSW  80  80  32.7   8.2  16.8  0.487
# 14849            Joel Embiid   C   28  PHI  66  66  34.6  11.0  20.1  0.548
# 1103           Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420
# 14096           LeBron James  SF   27  MIA  62  62  37.5  10.0  18.9  0.531
#
#        ...  Pts Max  Share                    Team   W   L   W/L%   GB   PS/G  \
# 6096   ...   1310.0  1.000   Golden State Warriors  73   9  0.890  0.0  114.9
# 14048  ...   1210.0  0.998              Miami Heat  66  16  0.805  0.0  102.9
# 143    ...   1210.0  0.998      Los Angeles Lakers  67  15  0.817  0.0  100.8
# 14913  ...   1230.0  0.991  Minnesota Timberwolves  58  24  0.707  0.0   94.5
# 6884   ...   1250.0  0.986   Oklahoma City Thunder  59  23  0.720  0.0  106.2
# 11346  ...   1130.0  0.986           Chicago Bulls  72  10  0.878  0.0  105.2
# 6076   ...   1230.0  0.980     Cleveland Cavaliers  61  21  0.744  0.0  102.1
# 13220  ...   1210.0  0.977           Chicago Bulls  62  20  0.756  0.0   98.6
# 6059   ...   1210.0  0.969     Cleveland Cavaliers  66  16  0.805  0.0  100.3
# 698    ...   1010.0  0.961          Denver Nuggets  47  25  0.653  5.0  115.1
# 1002   ...   1010.0  0.955         Houston Rockets  65  17  0.793  0.0  112.4
# 13354  ...   1010.0  0.952         Milwaukee Bucks  56  17  0.767  0.0  118.7
# 10738  ...    960.0  0.938           Chicago Bulls  67  15  0.817  0.0  109.9
# 11374  ...   1160.0  0.934           Chicago Bulls  62  20  0.756  0.0   96.7
# 12379  ...   1010.0  0.932         Milwaukee Bucks  60  22  0.732  0.0  118.1
# 10725  ...    960.0  0.928           Chicago Bulls  61  21  0.744  0.0  110.0
# 6601   ...   1300.0  0.922   Golden State Warriors  67  15  0.817  0.0  110.0
# 14849  ...   1000.0  0.915      Philadelphia 76ers  54  28  0.659  3.0  115.2
# 1103   ...   1240.0  0.904      Philadelphia 76ers  56  26  0.683  0.0   94.7
# 14096  ...   1210.0  0.888              Miami Heat  46  20  0.697  0.0   98.5
#
#         PA/G    SRS
# 6096   104.1  10.38
# 14048   95.0   7.03
# 143     92.3   8.41
# 14913   89.1   5.86
# 6884    99.8   6.66
# 11346   92.9  11.80
# 6076    95.6   6.17
# 13220   91.3   6.53
# 6059    91.4   8.68
# 698    110.1   4.82
# 1002   103.9   8.21
# 13354  108.6   9.41
# 10738   99.5  10.07
# 11374   89.6   7.24
# 12379  109.3   8.04
# 10725  101.0   8.57
# 6601    99.9  10.01
# 14849  110.9   4.37
# 1103    90.4   3.64
# 14096   92.5   5.72
#
# [20 rows x 41 columns]

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          61
# 3P            0
# 3PA           0
# 3P%        2102
# 2P            0
# 2PA           0
# 2P%         105
# eFG%         61
# FT            0
# FTA           0
# FT%         545
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats[pd.isnull(stats["3P%"])][["Player", "3PA"]].head()
# Out:
#              Player  3PA
# 2    Elden Campbell  0.0
# 3     Irving Thomas  0.0
# 18       Jack Haley  0.0
# 20      Keith Owens  0.0
# 30  Benoit Benjamin  0.0

# %%
stats[pd.isnull(stats["FT%"])][["Player", "FTA"]].head()
# Out:
#               Player  FTA
# 77        John Coker  0.0
# 92      Jason Sasser  0.0
# 103  Adrian Caldwell  0.0
# 119     Bruno Šundov  0.0
# 158   Jamal Robinson  0.0

# %%
stats =  stats.fillna(0)

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ["Age", "G", "GS", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%',
       'GB', 'PS/G', 'PA/G', 'SRS']

# %%
train = stats[(stats["Year"] < 2023)]
test = stats[stats["Year"] == 2023]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
reg.fit(train[predictors],train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination.sort_values("Share", ascending=False).head(20)
# Out:
#                         Player  Share  predictions
# 14849              Joel Embiid  0.915     0.202730
# 736               Nikola Jokić  0.674     0.173181
# 214      Giannis Antetokounmpo  0.606     0.225694
# 2898              Jayson Tatum  0.280     0.136305
# 1322   Shai Gilgeous-Alexander  0.046     0.150951
# 13682         Donovan Mitchell  0.030     0.087769
# 4274          Domantas Sabonis  0.027     0.092824
# 306                Luka Dončić  0.010     0.194363
# 6686             Stephen Curry  0.005     0.106164
# 10869             Jimmy Butler  0.003     0.112081
# 4272              De'Aaron Fox  0.002     0.094339
# 15106            Jalen Brunson  0.001     0.075504
# 12647                Ja Morant  0.001     0.126072
# 8671            Daniel Gafford  0.000     0.009864
# 10864              Cody Zeller  0.000    -0.000596
# 10863             Caleb Martin  0.000    -0.020550
# 10862              Bam Adebayo  0.000     0.063080
# 8688              Xavier Cooks  0.000    -0.020535
# 8687          Vernon Carey Jr.  0.000    -0.004369
# 8686                Taj Gibson  0.000    -0.013604
